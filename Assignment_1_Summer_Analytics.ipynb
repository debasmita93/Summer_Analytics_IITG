# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df = pd.read_csv(r"C:\Users\sahad\Downloads\Cars.csv")
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
df.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
list = ['mpg', 'cylinders',	'displacement',	'horsepower', 'weight',	'acceleration',	'model_year', 'origin',	'name']
name = list[8]
name
# Out:
# 'name'

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
df.isnull()
df.isnull().sum()
df.drop_duplicates()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
df['hp_weight_ratio'] = df['horsepower'] / df['weight']
df_indexed = df.set_index('hp_weight_ratio')
df_indexed.head()
# Out:
#                   mpg  cylinders  displacement  horsepower  weight  \
# hp_weight_ratio
# 0.037100         18.0          8         307.0       130.0    3504
# 0.044679         15.0          8         350.0       165.0    3693
# 0.043655         18.0          8         318.0       150.0    3436
# 0.043694         16.0          8         304.0       150.0    3433
# 0.040591         17.0          8         302.0       140.0    3449
#
#                  acceleration  model_year origin                       name
# hp_weight_ratio
# 0.037100                 12.0          70    usa  chevrolet chevelle malibu
# 0.044679                 11.5          70    usa          buick skylark 320
# 0.043655                 11.0          70    usa         plymouth satellite
# 0.043694                 12.0          70    usa              amc rebel sst
# 0.040591                 10.5          70    usa                ford torino

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
max_hp_car = df.loc[df['horsepower'].idxmax(), 'name']
max_hp_car
# Out:
# 'pontiac grand prix'

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
high_mpg_count = df[df['mpg'] >= 35].shape[0]
high_mpg_count
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
common_origin = df[(df['horsepower'] > 100) & (df['weight'] < 3000)]['origin'].mode()[0]
common_origin
# Out:
# 'usa'

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
mean_acc_japan = round(df[df['origin'] == 'japan']['acceleration'].mean(), 2)
mean_acc_japan
# Out:
# 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
year_highest_avg_mpg = df.groupby('model_year')['mpg'].mean().idxmax()
year_highest_avg_mpg
# Out:
# 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
median_mpg = df['mpg'].median()
above_median = df[df['mpg'] > median_mpg].copy()
above_median['hp_weight_ratio'] = above_median['horsepower'] / above_median['weight']
best_ratio = above_median['hp_weight_ratio'].max()
best_ratio_cars = above_median[above_median['hp_weight_ratio'] == best_ratio]['name'].unique()

# %%
median_mpg, above_median, best_ratio, best_ratio_cars
# Out:
# (23.0,
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
#  14   24.0          4         113.0        95.0    2372          15.0
#  18   27.0          4          97.0        88.0    2130          14.5
#  19   26.0          4          97.0        46.0    1835          20.5
#  20   25.0          4         110.0        87.0    2672          17.5
#  21   24.0          4         107.0        90.0    2430          14.5
#  ..    ...        ...           ...         ...     ...           ...
#  393  27.0          4         140.0        86.0    2790          15.6
#  394  44.0          4          97.0        52.0    2130          24.6
#  395  32.0          4         135.0        84.0    2295          11.6
#  396  28.0          4         120.0        79.0    2625          18.6
#  397  31.0          4         119.0        82.0    2720          19.4
#
#       model_year  origin                          name  hp_weight_ratio
#  14           70   japan         toyota corona mark ii         0.040051
#  18           70   japan                  datsun pl510         0.041315
#  19           70  europe  volkswagen 1131 deluxe sedan         0.025068
#  20           70  europe                   peugeot 504         0.032560
#  21           70  europe                   audi 100 ls         0.037037
#  ..          ...     ...                           ...              ...
#  393          82     usa               ford mustang gl         0.030824
#  394          82  europe                     vw pickup         0.024413
#  395          82     usa                 dodge rampage         0.036601
#  396          82     usa                   ford ranger         0.030095
#  397          82     usa                    chevy s-10         0.030147
#
#  [191 rows x 10 columns],
#  0.050581915846016116,
#  array(['bmw 2002'], dtype=object))

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
mpg_by_year_origin = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(data=mpg_by_year_origin, x='model_year', y='mpg', hue='origin', marker='o')
plt.title('Evolution of Average MPG Over Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sahad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sahad\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    sizes=(20, 200),
    hue_order=['japan', 'europe', 'usa'],
    alpha=0.7
)
plt.title('Horsepower vs Weight Colored by Origin and Sized by MPG')
plt.xlabel('Horsepower')
plt.ylabel('Weight')
plt.legend(title='Origin')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
car_counts = df['name'].value_counts()
multi_year_models = car_counts[car_counts > 1].index
grouped = df[df['name'].isin(multi_year_models)].groupby('name').agg(
    mpg_std=('mpg', 'std'),
    appearances=('mpg', 'count'),
    mpg_mean=('mpg', 'mean')
).reset_index()

consistent_models = grouped[(grouped['mpg_std'] < 1.0) & (grouped['appearances'] >= 2)]
consistent_models_sorted = consistent_models.sort_values(
    by=['appearances', 'mpg_mean'], ascending=[False, False]
)

best_consistent_models = consistent_models_sorted[['name', 'appearances', 'mpg_mean']]
best_ratio_cars, best_consistent_models
# Out:
# (array(['bmw 2002'], dtype=object),
#                           name  appearances   mpg_mean
#  26           ford galaxie 500            3  14.333333
#  41          plymouth fury iii            3  14.333333
#  50        toyota corolla 1200            2  31.500000
#  35                  mazda 626            2  31.450000
#  54          volkswagen rabbit            2  29.250000
#  21               datsun pl510            2  27.000000
#  46                  saab 99le            2  24.500000
#  52             toyota mark ii            2  19.500000
#  22                dodge aspen            2  18.850000
#  10  chevrolet chevelle malibu            2  17.500000
#  4            amc matador (sw)            2  14.500000
#  28      ford gran torino (sw)            2  13.500000
#  29                   ford ltd            2  13.500000)

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
